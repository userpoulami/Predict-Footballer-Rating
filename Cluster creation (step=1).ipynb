# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data.csv",index_col=0)

# %%
df.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183978 entries, 0 to 183977
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   183978 non-null  int64
#  1   player_fifa_api_id   183978 non-null  int64
#  2   player_api_id        183978 non-null  int64
#  3   date                 183978 non-null  object
#  4   overall_rating       183142 non-null  float64
#  5   potential            183142 non-null  float64
#  6   preferred_foot       183142 non-null  object
#  7   attacking_work_rate  180748 non-null  object
#  8   defensive_work_rate  183142 non-null  object
#  9   crossing             183142 non-null  float64
#  10  finishing            183142 non-null  float64
#  11  heading_accuracy     183142 non-null  float64
#  12  short_passing        183142 non-null  float64
#  13  volleys              181265 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id  player_fifa_api_id  player_api_id  overall_rating  \
# count  183978.00000       183978.000000  183978.000000   183142.000000
# mean    91989.50000       165671.524291  135900.617324       68.600015
# std     53110.01825        53851.094769  136927.840510        7.041139
# min         1.00000            2.000000    2625.000000       33.000000
# 25%     45995.25000       155798.000000   34763.000000       64.000000
# 50%     91989.50000       183488.000000   77741.000000       69.000000
# 75%    137983.75000       199848.000000  191080.000000       73.000000
# max    183978.00000       234141.000000  750584.000000       94.000000
#
#            potential       crossing      finishing  heading_accuracy  \
# count  183142.000000  183142.000000  183142.000000     183142.000000
# mean       73.460353      55.086883      49.921078         57.266023
# std         6.592271      17.242135      19.038705         16.488905
# ...

# %%
df.iloc[:,1:]
# Out:
#         player_fifa_api_id  player_api_id                 date  \
# 0                   218353         505942  2016-02-18 00:00:00
# 1                   218353         505942  2015-11-19 00:00:00
# 2                   218353         505942  2015-09-21 00:00:00
# 3                   218353         505942  2015-03-20 00:00:00
# 4                   218353         505942  2007-02-22 00:00:00
# ...                    ...            ...                  ...
# 183973              102359          39902  2009-08-30 00:00:00
# 183974              102359          39902  2009-02-22 00:00:00
# 183975              102359          39902  2008-08-30 00:00:00
# 183976              102359          39902  2007-08-30 00:00:00
# 183977              102359          39902  2007-02-22 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# 0                 67.0       71.0          right              medium
# ...

# %% [markdown]
# # Null Value

# %%
df.iloc[:,1:].isnull().sum()
# Out:
# player_fifa_api_id        0
# player_api_id             0
# date                      0
# overall_rating          836
# potential               836
# preferred_foot          836
# attacking_work_rate    3230
# defensive_work_rate     836
# crossing                836
# finishing               836
# heading_accuracy        836
# short_passing           836
# volleys                2713
# dribbling               836
# curve                  2713
# free_kick_accuracy      836
# long_passing            836
# ball_control            836
# acceleration            836
# sprint_speed            836
# agility                2713
# reactions               836
# balance                2713
# shot_power              836
# jumping                2713
# stamina                 836
# strength                836
# long_shots              836
# aggression              836
# interceptions           836
# positioning             836
# vision                 2713
# penalties               836
# ...

# %%
# We have to remove all this 836 column
df[df["overall_rating"].isnull()==True]
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 483        484               33022          31684  2007-02-22 00:00:00
# 983        984              111085          29904  2007-02-22 00:00:00
# 1752      1753              165740          24159  2007-02-22 00:00:00
# 2089      2090              176941          31916  2007-02-22 00:00:00
# 2482      2483              177615          37249  2007-02-22 00:00:00
# ...        ...                 ...            ...                  ...
# 182587  182588              116368          25538  2007-02-22 00:00:00
# 183249  183250              139865          32633  2007-02-22 00:00:00
# 183309  183310              141272          33823  2007-02-22 00:00:00
# 183361  183362              168650          25772  2007-02-22 00:00:00
# 183487  183488               28765          38843  2007-02-22 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# ...

# %%
df[df["overall_rating"].isnull()==True].shape
# Out:
# (836, 42)

# %%
# index list of all null rows
list_id_null=[]

for i in df[df["overall_rating"].isnull()==True]["id"]:
    list_id_null.append(i-1)

# %%
len(list_id_null)
# Out:
# 836

# %%
df.shape
# Out:
# (183978, 42)

# %%
# drop all rows 
df.drop(list_id_null,axis=0,inplace=True)

# %%
df.shape
# Out:
# (183142, 42)

# %%
df
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 0            1              218353         505942  2016-02-18 00:00:00
# 1            2              218353         505942  2015-11-19 00:00:00
# 2            3              218353         505942  2015-09-21 00:00:00
# 3            4              218353         505942  2015-03-20 00:00:00
# 4            5              218353         505942  2007-02-22 00:00:00
# ...        ...                 ...            ...                  ...
# 183973  183974              102359          39902  2009-08-30 00:00:00
# 183974  183975              102359          39902  2009-02-22 00:00:00
# 183975  183976              102359          39902  2008-08-30 00:00:00
# 183976  183977              102359          39902  2007-08-30 00:00:00
# 183977  183978              102359          39902  2007-02-22 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.iloc[:,1:].isnull().sum()
# Out:
# player_fifa_api_id        0
# player_api_id             0
# date                      0
# overall_rating            0
# potential                 0
# preferred_foot            0
# attacking_work_rate    2394
# defensive_work_rate       0
# crossing                  0
# finishing                 0
# heading_accuracy          0
# short_passing             0
# volleys                1877
# dribbling                 0
# curve                  1877
# free_kick_accuracy        0
# long_passing              0
# ball_control              0
# acceleration              0
# sprint_speed              0
# agility                1877
# reactions                 0
# balance                1877
# shot_power                0
# jumping                1877
# stamina                   0
# strength                  0
# long_shots                0
# aggression                0
# interceptions             0
# positioning               0
# vision                 1877
# penalties                 0
# ...

# %%
df["attacking_work_rate"].dtype
# Out:
# dtype('O')

# %%
for i in ["attacking_work_rate","volleys","curve","agility" ,"balance","jumping","vision","sliding_tackle"]:
    print("Percentage of null values in",i,"column",df[i].isnull().mean(),"and datatype is",df[i].dtype)
# Out:
# Percentage of null values in attacking_work_rate column 0.013071824049098514 and datatype is object
# Percentage of null values in volleys column 0.01024887791986546 and datatype is float64
# Percentage of null values in curve column 0.01024887791986546 and datatype is float64
# Percentage of null values in agility column 0.01024887791986546 and datatype is float64
# Percentage of null values in balance column 0.01024887791986546 and datatype is float64
# Percentage of null values in jumping column 0.01024887791986546 and datatype is float64
# Percentage of null values in vision column 0.01024887791986546 and datatype is float64
# Percentage of null values in sliding_tackle column 0.01024887791986546 and datatype is float64

# %%
df["attacking_work_rate"].value_counts()
# Out:
# medium    125070
# high       42823
# low         8569
# None        3639
# norm         348
# y            106
# le           104
# stoc          89
# Name: attacking_work_rate, dtype: int64

# %%
df.shape
# Out:
# (183142, 42)

# %%
df.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
obj = [col for col in df.columns if df[col].dtypes == 'O']
df_obj=df[obj]

# %%
df_obj.shape
# Out:
# (183142, 4)

# %%
df[obj]
# Out:
#                        date preferred_foot attacking_work_rate  \
# 0       2016-02-18 00:00:00          right              medium
# 1       2015-11-19 00:00:00          right              medium
# 2       2015-09-21 00:00:00          right              medium
# 3       2015-03-20 00:00:00          right              medium
# 4       2007-02-22 00:00:00          right              medium
# ...                     ...            ...                 ...
# 183137  2009-08-30 00:00:00          right              medium
# 183138  2009-02-22 00:00:00          right              medium
# 183139  2008-08-30 00:00:00          right              medium
# 183140  2007-08-30 00:00:00          right              medium
# 183141  2007-02-22 00:00:00          right              medium
#
#        defensive_work_rate
# 0                   medium
# 1                   medium
# 2                   medium
# 3                   medium
# 4                   medium
# ...                    ...
# ...

# %%
num = [col for col in df.columns if df[col].dtypes != 'O']

# %%
df[num]
# Out:
#             id  player_fifa_api_id  player_api_id  overall_rating  potential  \
# 0            1              218353         505942            67.0       71.0
# 1            2              218353         505942            67.0       71.0
# 2            3              218353         505942            62.0       66.0
# 3            4              218353         505942            61.0       65.0
# 4            5              218353         505942            61.0       65.0
# ...        ...                 ...            ...             ...        ...
# 183137  183974              102359          39902            83.0       85.0
# 183138  183975              102359          39902            78.0       80.0
# 183139  183976              102359          39902            77.0       80.0
# 183140  183977              102359          39902            78.0       81.0
# 183141  183978              102359          39902            80.0       81.0
#
# ...

# %%
df[num].isnull().sum()
# Out:
# id                       0
# player_fifa_api_id       0
# player_api_id            0
# overall_rating           0
# potential                0
# crossing                 0
# finishing                0
# heading_accuracy         0
# short_passing            0
# volleys               1877
# dribbling                0
# curve                 1877
# free_kick_accuracy       0
# long_passing             0
# ball_control             0
# acceleration             0
# sprint_speed             0
# agility               1877
# reactions                0
# balance               1877
# shot_power               0
# jumping               1877
# stamina                  0
# strength                 0
# long_shots               0
# aggression               0
# interceptions            0
# positioning              0
# vision                1877
# penalties                0
# marking                  0
# standing_tackle          0
# sliding_tackle        1877
# gk_diving                0
# ...

# %%
df_num=df[num].iloc[:,3:]

# %%
df_num
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183137            83.0       85.0      84.0       77.0              59.0
# 183138            78.0       80.0      74.0       76.0              53.0
# 183139            77.0       80.0      74.0       71.0              53.0
# 183140            78.0       81.0      74.0       64.0              57.0
# 183141            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
list_of_col=df_num.columns

# %%
list_of_col
# Out:
# Index(['overall_rating', 'potential', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'marking',
#        'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes'],
#       dtype='object')

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer()
imputer.fit(df_num)
Xtrans = imputer.transform(df_num)

# %%
Xtrans
# Out:
# array([[67., 71., 49., ..., 10.,  8.,  8.],
#        [67., 71., 49., ..., 10.,  8.,  8.],
#        [62., 66., 49., ..., 10.,  8.,  8.],
#        ...,
#        [77., 80., 74., ..., 73., 20., 20.],
#        [78., 81., 74., ..., 73., 20., 20.],
#        [80., 81., 74., ..., 78.,  7., 15.]])

# %%
Xtrans.shape
# Out:
# (183142, 35)

# %%
df_trans= pd.DataFrame(data = Xtrans, columns = list_of_col)

# %%
df_trans
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183137            83.0       85.0      84.0       77.0              59.0
# 183138            78.0       80.0      74.0       76.0              53.0
# 183139            77.0       80.0      74.0       71.0              53.0
# 183140            78.0       81.0      74.0       64.0              57.0
# 183141            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
df_trans.shape
# Out:
# (183142, 35)

# %%
df_trans.isnull().sum()
# Out:
# overall_rating        0
# potential             0
# crossing              0
# finishing             0
# heading_accuracy      0
# short_passing         0
# volleys               0
# dribbling             0
# curve                 0
# free_kick_accuracy    0
# long_passing          0
# ball_control          0
# acceleration          0
# sprint_speed          0
# agility               0
# reactions             0
# balance               0
# shot_power            0
# jumping               0
# stamina               0
# strength              0
# long_shots            0
# aggression            0
# interceptions         0
# positioning           0
# vision                0
# penalties             0
# marking               0
# standing_tackle       0
# sliding_tackle        0
# gk_diving             0
# gk_handling           0
# gk_kicking            0
# gk_positioning        0
# gk_reflexes           0
# dtype: int64

# %%
df_obj.isnull().sum()
# Out:
# date                      0
# preferred_foot            0
# attacking_work_rate    2394
# defensive_work_rate       0
# dtype: int64

# %%
df_obj["attacking_work_rate"].fillna(df_obj["attacking_work_rate"].mode()[0],inplace=True)
# Out:
# C:\Users\Sagnik\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df_obj
# Out:
#                        date preferred_foot attacking_work_rate  \
# 0       2016-02-18 00:00:00          right              medium
# 1       2015-11-19 00:00:00          right              medium
# 2       2015-09-21 00:00:00          right              medium
# 3       2015-03-20 00:00:00          right              medium
# 4       2007-02-22 00:00:00          right              medium
# ...                     ...            ...                 ...
# 183137  2009-08-30 00:00:00          right              medium
# 183138  2009-02-22 00:00:00          right              medium
# 183139  2008-08-30 00:00:00          right              medium
# 183140  2007-08-30 00:00:00          right              medium
# 183141  2007-02-22 00:00:00          right              medium
#
#        defensive_work_rate
# 0                   medium
# 1                   medium
# 2                   medium
# 3                   medium
# 4                   medium
# ...                    ...
# ...

# %%
df_obj.isnull().sum()
# Out:
# date                   0
# preferred_foot         0
# attacking_work_rate    0
# defensive_work_rate    0
# dtype: int64

# %%
df_obj.shape
# Out:
# (183142, 4)

# %%
df_final=pd.concat([df_trans,df_obj],axis=1)

# %%
df_final
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183137            83.0       85.0      84.0       77.0              59.0
# 183138            78.0       80.0      74.0       76.0              53.0
# 183139            77.0       80.0      74.0       71.0              53.0
# 183140            78.0       81.0      74.0       64.0              57.0
# 183141            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
df_final.isnull().sum()
# Out:
# overall_rating         0
# potential              0
# crossing               0
# finishing              0
# heading_accuracy       0
# short_passing          0
# volleys                0
# dribbling              0
# curve                  0
# free_kick_accuracy     0
# long_passing           0
# ball_control           0
# acceleration           0
# sprint_speed           0
# agility                0
# reactions              0
# balance                0
# shot_power             0
# jumping                0
# stamina                0
# strength               0
# long_shots             0
# aggression             0
# interceptions          0
# positioning            0
# vision                 0
# penalties              0
# marking                0
# standing_tackle        0
# sliding_tackle         0
# gk_diving              0
# gk_handling            0
# gk_kicking             0
# gk_positioning         0
# gk_reflexes            0
# date                   0
# preferred_foot         0
# ...

# %%
df_final
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183137            83.0       85.0      84.0       77.0              59.0
# 183138            78.0       80.0      74.0       76.0              53.0
# 183139            77.0       80.0      74.0       71.0              53.0
# 183140            78.0       81.0      74.0       64.0              57.0
# 183141            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %% [markdown]
# # Replace obj using map

# %%
#'attacking_work_rate', 'defensive_work_rate' both have 4 important class medium,high,low,normal,none

# %%
df_final.columns
# Out:
# Index(['overall_rating', 'potential', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'marking',
#        'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes', 'date', 'preferred_foot',
#        'attacking_work_rate', 'defensive_work_rate'],
#       dtype='object')

# %%
df_final[obj]
# Out:
#                        date preferred_foot attacking_work_rate  \
# 0       2016-02-18 00:00:00          right              medium
# 1       2015-11-19 00:00:00          right              medium
# 2       2015-09-21 00:00:00          right              medium
# 3       2015-03-20 00:00:00          right              medium
# 4       2007-02-22 00:00:00          right              medium
# ...                     ...            ...                 ...
# 183137  2009-08-30 00:00:00          right              medium
# 183138  2009-02-22 00:00:00          right              medium
# 183139  2008-08-30 00:00:00          right              medium
# 183140  2007-08-30 00:00:00          right              medium
# 183141  2007-02-22 00:00:00          right              medium
#
#        defensive_work_rate
# 0                   medium
# 1                   medium
# 2                   medium
# 3                   medium
# 4                   medium
# ...                    ...
# ...

# %%
df_final["defensive_work_rate"].value_counts()
# Out:
# medium    130846
# high       27041
# low        18432
# _0          2394
# o           1550
# 1            441
# ormal        348
# 2            342
# 3            258
# 5            234
# 7            217
# 6            197
# 0            197
# 9            152
# 4            116
# es           106
# ean          104
# tocky         89
# 8             78
# Name: defensive_work_rate, dtype: int64

# %%
dd=df_final

# %%
dd.shape[0]
# Out:
# 183142

# %%
id=[]
for i in range(0,dd.shape[0]):
    id.append(i)

# %%
dd["id"]=id

# %%
dd["attacking_work_rate"].value_counts()
# Out:
# medium    127464
# high       42823
# low         8569
# None        3639
# norm         348
# y            106
# le           104
# stoc          89
# Name: attacking_work_rate, dtype: int64

# %%
list_id_of_attacking_work_rate=[]

# %%
for i in dd[dd["attacking_work_rate"]=="y"]["id"]:
     list_id_of_attacking_work_rate.append(i)

# %%
for i in dd[dd["attacking_work_rate"]=="le"]["id"]:
     list_id_of_attacking_work_rate.append(i)

# %%
for i in dd[dd["attacking_work_rate"]=="stoc"]["id"]:
     list_id_of_attacking_work_rate.append(i)

# %%
dd.drop(list_id_of_attacking_work_rate,axis=0,inplace=True)

# %%
dd["attacking_work_rate"].value_counts()
# Out:
# medium    127464
# high       42823
# low         8569
# None        3639
# norm         348
# Name: attacking_work_rate, dtype: int64

# %%
dd["defensive_work_rate"].value_counts()
# Out:
# medium    130846
# high       27041
# low        18432
# _0          2394
# o           1550
# 1            441
# ormal        348
# 2            342
# 3            258
# 5            234
# 7            217
# 0            197
# 6            197
# 9            152
# 4            116
# 8             78
# Name: defensive_work_rate, dtype: int64

# %%
list_of_id_defensive_work_rate=[]

# %%
for i in dd[dd["defensive_work_rate"]=="_0"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="1"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="2"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="3"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="4"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="5"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="6"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="7"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="8"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="9"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
for i in dd[dd["defensive_work_rate"]=="o"]["id"]:
     list_of_id_defensive_work_rate.append(i)

# %%
dd.drop(list_of_id_defensive_work_rate,axis=0,inplace=True)

# %%
dd["defensive_work_rate"].value_counts()
# Out:
# medium    130846
# high       27041
# low        18432
# ormal        348
# 0            197
# Name: defensive_work_rate, dtype: int64

# %%
dd["preferred_foot"]=dd["preferred_foot"].map({'right':0,"left":1}).astype(int)

# %%
dd["defensive_work_rate"]=dd["defensive_work_rate"].map({"medium":0,"high":1,"low":2,"ormal":3,"0":4})

# %%
dd["attacking_work_rate"]=dd["attacking_work_rate"].map({"medium":0,"high":1,"low":2,"None":3,"norm":4})

# %%
dd
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183137            83.0       85.0      84.0       77.0              59.0
# 183138            78.0       80.0      74.0       76.0              53.0
# 183139            77.0       80.0      74.0       71.0              53.0
# 183140            78.0       81.0      74.0       64.0              57.0
# 183141            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176864 entries, 0 to 183141
# Data columns (total 40 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   overall_rating       176864 non-null  float64
#  1   potential            176864 non-null  float64
#  2   crossing             176864 non-null  float64
#  3   finishing            176864 non-null  float64
#  4   heading_accuracy     176864 non-null  float64
#  5   short_passing        176864 non-null  float64
#  6   volleys              176864 non-null  float64
#  7   dribbling            176864 non-null  float64
#  8   curve                176864 non-null  float64
#  9   free_kick_accuracy   176864 non-null  float64
#  10  long_passing         176864 non-null  float64
#  11  ball_control         176864 non-null  float64
#  12  acceleration         176864 non-null  float64
#  13  sprint_speed         176864 non-null  float64
# ...

# %%
dd['date']= pd.to_datetime(dd['date'],format="%Y/%m/%d")

# %%
dd
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183137            83.0       85.0      84.0       77.0              59.0
# 183138            78.0       80.0      74.0       76.0              53.0
# 183139            77.0       80.0      74.0       71.0              53.0
# 183140            78.0       81.0      74.0       64.0              57.0
# 183141            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
import datetime 
today = datetime.date.today()

# %%
today
# Out:
# datetime.date(2022, 3, 19)

# %%
dt = pd.to_datetime(i, format='%Y/%m/%d')
dt1 = pd.to_datetime('2022-03-18', format='%Y/%m/%d')

# %%
no_of_days=[]

for i in dd["date"]:
    dt = pd.to_datetime(i, format='%Y/%m/%d')
    dt1 = pd.to_datetime('2022-03-18', format='%Y/%m/%d')
    no_of_days.append((dt1-dt).days)

# %%
dd["experience_no_of_days"]=no_of_days

# %%
dd.drop(['date',"id"],inplace=True,axis=1)

# %%
dd
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183137            83.0       85.0      84.0       77.0              59.0
# 183138            78.0       80.0      74.0       76.0              53.0
# 183139            77.0       80.0      74.0       71.0              53.0
# 183140            78.0       81.0      74.0       64.0              57.0
# 183141            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
# # For data analysis
# from pandas_profiling import ProfileReport
# pf=ProfileReport(dd)
# pf.to_file("report.html")

# %%
dd["overall_rating"]
# Out:
# Index(['overall_rating', 'potential', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'marking',
#        'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes', 'preferred_foot',
#        'attacking_work_rate', 'defensive_work_rate', 'experience_no_of_days'],
#       dtype='object')

# %%
dd.to_csv('dd.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-43d922f45073> in <module>
# ----> 1 dd.to_csv('dd.csv')
#
# NameError: name 'dd' is not defined

# %%
import pandas as pd
dd=pd.read_csv("dd.csv")

# %%
dd_target=dd["overall_rating"]

# %%
dd.drop(["Unnamed: 0","overall_rating"],axis=1,inplace=True)

# %%
dd
# Out:
#         potential  crossing  finishing  heading_accuracy  short_passing  \
# 0            71.0      49.0       44.0              71.0           61.0
# 1            71.0      49.0       44.0              71.0           61.0
# 2            66.0      49.0       44.0              71.0           61.0
# 3            65.0      48.0       43.0              70.0           60.0
# 4            65.0      48.0       43.0              70.0           60.0
# ...           ...       ...        ...               ...            ...
# 176859       85.0      84.0       77.0              59.0           89.0
# 176860       80.0      74.0       76.0              53.0           84.0
# 176861       80.0      74.0       71.0              53.0           84.0
# 176862       81.0      74.0       64.0              57.0           86.0
# 176863       81.0      74.0       68.0              57.0           88.0
#
#         volleys  dribbling  curve  free_kick_accuracy  long_passing  ...  \
# ...

# %%
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
from sklearn.cluster import KMeans

wcss=[]
for i in range (1,10):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(dd)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,10),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from yellowbrick.cluster import SilhouetteVisualizer
km = KMeans(n_clusters=2, init='k-means++')
visualizer = SilhouetteVisualizer(km, colors='yellowbrick')
visualizer.fit(dd)
# Out:
# SilhouetteVisualizer(ax=<AxesSubplot:>, colors='yellowbrick',
#                      estimator=KMeans(n_clusters=2))

# %%
from yellowbrick.cluster import SilhouetteVisualizer
km = KMeans(n_clusters=3, init='k-means++')
visualizer = SilhouetteVisualizer(km, colors='yellowbrick')
visualizer.fit(dd)
# Out:
# SilhouetteVisualizer(ax=<AxesSubplot:>, colors='yellowbrick',
#                      estimator=KMeans(n_clusters=3))

# %%
from yellowbrick.cluster import SilhouetteVisualizer
km = KMeans(n_clusters=4, init='k-means++')
visualizer = SilhouetteVisualizer(km, colors='yellowbrick')
visualizer.fit(dd)
# Out:
# SilhouetteVisualizer(ax=<AxesSubplot:>, colors='yellowbrick',
#                      estimator=KMeans(n_clusters=4))

# %%
# So we choose no of cluster should be 3

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("dd.csv")

# %%
df_target=df["overall_rating"]

# %%
df.drop(["Unnamed: 0"],inplace=True,axis=1)

# %%
df.drop(["overall_rating"],inplace=True,axis=1)

# %%
df
# Out:
#         potential  crossing  finishing  heading_accuracy  short_passing  \
# 0            71.0      49.0       44.0              71.0           61.0
# 1            71.0      49.0       44.0              71.0           61.0
# 2            66.0      49.0       44.0              71.0           61.0
# 3            65.0      48.0       43.0              70.0           60.0
# 4            65.0      48.0       43.0              70.0           60.0
# ...           ...       ...        ...               ...            ...
# 176859       85.0      84.0       77.0              59.0           89.0
# 176860       80.0      74.0       76.0              53.0           84.0
# 176861       80.0      74.0       71.0              53.0           84.0
# 176862       81.0      74.0       64.0              57.0           86.0
# 176863       81.0      74.0       68.0              57.0           88.0
#
#         volleys  dribbling  curve  free_kick_accuracy  long_passing  ...  \
# ...

# %%
from sklearn.cluster import KMeans
km=KMeans(n_clusters=3,init='k-means++',random_state=42)
km.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
pred_y=km.fit_predict(dd)

# %%
count_arr = np.bincount(pred_y)

# %%
count_arr
# Out:
# array([69901, 36462, 70501], dtype=int64)

# %%
for i in range(0,3):
    print("Total no of observation in cluster",i, ": ", count_arr[i])
# Out:
# Total no of observation in cluster 0 :  69901
# Total no of observation in cluster 1 :  36462
# Total no of observation in cluster 2 :  70501

# %%
count_arr.sum()
# Out:
# 176864

# %%
df.shape
# Out:
# (176864, 38)

# %%
df["lable_cluster"]=pred_y

# %%
df
# Out:
#         potential  crossing  finishing  heading_accuracy  short_passing  \
# 0            71.0      49.0       44.0              71.0           61.0
# 1            71.0      49.0       44.0              71.0           61.0
# 2            66.0      49.0       44.0              71.0           61.0
# 3            65.0      48.0       43.0              70.0           60.0
# 4            65.0      48.0       43.0              70.0           60.0
# ...           ...       ...        ...               ...            ...
# 176859       85.0      84.0       77.0              59.0           89.0
# 176860       80.0      74.0       76.0              53.0           84.0
# 176861       80.0      74.0       71.0              53.0           84.0
# 176862       81.0      74.0       64.0              57.0           86.0
# 176863       81.0      74.0       68.0              57.0           88.0
#
#         volleys  dribbling  curve  free_kick_accuracy  long_passing  ...  \
# ...

# %%
dd=pd.concat([df_target,df],axis=1)

# %%
dd
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 176859            83.0       85.0      84.0       77.0              59.0
# 176860            78.0       80.0      74.0       76.0              53.0
# 176861            77.0       80.0      74.0       71.0              53.0
# 176862            78.0       81.0      74.0       64.0              57.0
# 176863            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
df1=dd[dd["lable_cluster"]==0]

# %%
df2=dd[dd["lable_cluster"]==1]

# %%
df3=dd[dd["lable_cluster"]==2]

# %%
df1.shape
# Out:
# (69901, 40)

# %%
df2.shape
# Out:
# (36462, 40)

# %%
df3.shape
# Out:
# (70501, 40)

# %%
df1
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 20                70.0       79.0      77.0       50.0              51.0
# 21                70.0       79.0      77.0       50.0              51.0
# 22                69.0       79.0      77.0       50.0              50.0
# 23                69.0       79.0      77.0       50.0              50.0
# 24                69.0       80.0      77.0       50.0              50.0
# ...                ...        ...       ...        ...               ...
# 176851            68.0       79.0      71.0       48.0              63.0
# 176854            78.0       78.0      77.0       70.0              59.0
# 176855            81.0       81.0      80.0       72.0              59.0
# 176856            81.0       81.0      80.0       72.0              59.0
# 176857            81.0       85.0      81.0       78.0              59.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
df1.to_csv('cluster01.csv')

# %%
df2.to_csv('cluster02.csv')

# %%
df3.to_csv('cluster03.csv')

# %%
dd.shape
# Out:
# (176864, 41)

# %%
import pickle
pickle.dump(km,open('cluster.pickle','wb'))

# %%
saved_model = pickle.load(open("cluster.pickle",'rb'))

# %%
saved_model.predict([[71.0,49.0,44.0,71.0,61.0,44.0,51.0,45.0,39.0,64.0,49.0,60.0,64.0,59.0,47.0,65.0,55.0,58.0,54.0,76.0,35.0,71.0,70.0,45.0,54.0,48.0,65.0,69.0,69.0,6.0,11.0,10.0,8.0,8.0,0.0,0.0,0.0,2220.0]])
# Out:
# C:\Users\Sagnik\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([2])
